# %%
from PIL import Image

# Text Variables
Header = '>>>This resume was generated entirely in Python. For full sourcecode, view my portfolio.'
Name = 'Utkarsh Maheshwari'
Title = 'Data Science & Analytics'
Contact = 'Toronto, ON\n647-886-3590\nutkarsh95m@gmail.com\nhttps://www.linkedin.com/in/analystutkarsh/\nhttps://github.com/utkarsh95m'
ProjectsHeader = 'Work Experience'
ProjectOneTitle = 'Tutor & Peer Leader @ George Brown College        Sep 2022-Present'
ProjectOneTime  = 'Sept 2022- Present'
ProjectOneDesc = '- Served as a peer leader for English communication classes for undergraduate \n  students, leading and preparing materials for 2 courses per semester with a \n  90% satisfaction rate from students.\n- Taught and provided individualized support to 100+ students per semester in\n  coding and the English language, including speaking, writing, and reading, \n  resulting in a 65% improvement in students\'language skills.'
ProjectTwoTitle = 'Marketing Software & Data Analyst @ iRestify      Jan 2022-Jul 2022'
ProjectTwoTime= 'Jan 2022- Jul 2022'
ProjectTwoDesc = '- Predictive Modeling: Used regression techniques like Linear, Multi-Linear, and \n  Random Forest Regression to build predictive models to forecast the demand for \n  commercial property cleaning services.\n- Customer Segmentation: Used clustering techniques like Hierarchical clustering to \n  segment customers based on their cleaning requirements.\n- Automation: Used multiple software solutions, resulting in a 30% reduction in manual \n  data entry errors.\n- Designed and developed interactive dashboards for data visualization using Power BI \n  for sales and marketing teams.'
ProjectThreeTitle = 'Seller Support Associate @ Amazon                       Oct 2020- May 2021'
ProjectThreeTime = 'Oct 2020- May 2021'
ProjectThreeDesc = '- Provided exceptional support to over 500 Amazon sellers and merchants as part of the \n  CXAC team, successfully resolving 95% of all customer issues through proactive \n  problem-solving in every interaction\n- Proactively identified and addressed chronic system issues, resulting in a 20% reduction \n  in operational support requests and a 30% improvement in response time.'
WorkHeader = 'Achievements'
WorkOneTitle = 'Microsoft x Technation AI for Accessibility 2023 Finalist'

WorkOneDesc = '- Made an emotion labelling AI model to detect emotions in any text for helping \n  individuals with autism spectrum disorder'

EduHeader = 'Education'
EduOneTitle = 'George Brown College, Postgraduate Program in Business Analytics'
EduOneTime = 'Sept 2022- Apr 2023'
EduOneDesc = '- Major: Data Science'
EduTwoTitle = 'National Institute of Fashion Technology, Bachelor of Technology'
EduTwoTime = 'Jul 2013- Oct 2017'
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Pandas\n- NumPy\n- Power BI & Tableau\n- SAS\n- Command Line\n- Git and Version Control\n- SQL & BigQuery\n- APIs\n- Probability/Statistics\n- Data Manipulation\n- Excel\n- Machine Learning'
ExtrasTitle = 'Hobbies'
ExtrasDesc = '- Coding\n- Gaming\n- Cooking\n- Hiking\n- Creative Writing'
CodeTitle = 'View Portfolio'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(9, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Header, (.02,.980), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.940), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.910), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(ProjectsHeader, (.02,.860), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.832), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.720), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.02,.680), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.52), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.02,.48), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.39), weight='regular', fontsize=9)
plt.annotate(WorkHeader, (.02,.34), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(WorkOneTitle, (.02,.31), weight='bold', fontsize=10)
plt.annotate(WorkOneDesc, (.04,.27), weight='regular', fontsize=9)
plt.annotate(EduHeader, (.02,.24), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.21), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.19), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduOneDesc, (.04,.17), weight='regular', fontsize=9)
plt.annotate(EduTwoTitle, (.02,.14), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.12), weight='regular', fontsize=9, alpha=.6)
plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.56), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(ExtrasTitle, (.7,.43), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ExtrasDesc, (.7,.335), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(CodeTitle, (.7,.24), weight='bold', fontsize=10, color='#ffffff')

#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('utkarsh_qr.png')
imagebox = OffsetImage(arr_code, zoom=0.5)
ab = AnnotationBbox(imagebox, (0.84, 0.12))
ax.add_artist(ab)

plt.savefig('utkarsh_data_science.png', dpi=300, bbox_inches='tight')

# Convert the PNG to a PDF
img = Image.open('utkarsh_data_science.png')
img.convert('RGB').save('utkarsh_data_science.pdf')
